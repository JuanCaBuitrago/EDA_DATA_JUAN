# %%
import pandas as pd
import matplotlib as plt
import matplotlib.pyplot as plt
import glob 
import matplotlib.dates as mdates
import seaborn as sns

# %%
#df_coins=(r )
df_bitcoin=pd.read_csv(r"C:\Users\Usuario\Documents\Proyecto EDA\src\data\coin_Bitcoin.csv") 
df_cardano = pd.read_csv(r"C:\Users\Usuario\Documents\Proyecto EDA\src\data\coin_Cardano.csv")
df_dogecoin=pd.read_csv(r"C:\Users\Usuario\Documents\Proyecto EDA\src\data\coin_Dogecoin.csv")
df_ethereum=pd.read_csv(r"C:\Users\Usuario\Documents\Proyecto EDA\src\data\coin_Ethereum.csv")
df_polkadot=pd.read_csv(r"C:\Users\Usuario\Documents\Proyecto EDA\src\data\coin_Polkadot.csv")
df_solana=pd.read_csv(r"C:\Users\Usuario\Documents\Proyecto EDA\src\data\coin_Solana.csv")
df_tether=pd.read_csv(r"C:\Users\Usuario\Documents\Proyecto EDA\src\data\coin_Tether.csv")
df_USDC=pd.read_csv(r"C:\Users\Usuario\Documents\Proyecto EDA\src\data\coin_USDCoin.csv")
df_XRP=pd.read_csv(r"C:\Users\Usuario\Documents\Proyecto EDA\src\data\coin_XRP.csv")

# %%
df_bitcoin['Date']= pd.to_datetime(df_bitcoin['Date']) # Cambiar la columna 'Date' a  tipo datatime  para cada una de los archivos. 
df_bitcoin.set_index('Date', inplace=True)  #Colocar la columna 'Date' como indice para poder establecer un parametro comun de fechas.

df_cardano['Date']= pd.to_datetime(df_cardano['Date'])
df_cardano.set_index('Date', inplace=True)

df_dogecoin['Date']= pd.to_datetime(df_dogecoin['Date'])
df_dogecoin.set_index('Date', inplace=True)

df_ethereum['Date']= pd.to_datetime(df_ethereum['Date'])
df_ethereum.set_index('Date', inplace=True)

df_polkadot['Date']= pd.to_datetime(df_polkadot['Date'])
df_polkadot.set_index('Date', inplace=True)

df_solana['Date']= pd.to_datetime(df_solana['Date'])
df_solana.set_index('Date', inplace=True)

df_tether['Date']= pd.to_datetime(df_tether['Date'])
df_tether.set_index('Date', inplace=True)

df_USDC['Date']= pd.to_datetime(df_USDC['Date'])
df_USDC.set_index('Date', inplace=True)

df_XRP['Date']= pd.to_datetime(df_XRP['Date'])
df_XRP.set_index('Date', inplace=True)

# %%
df_dogecoin.head()
# Out:
#                      SNo      Name Symbol      High       Low      Open  \
# Date
# 2013-12-16 23:59:59    1  Dogecoin   DOGE  0.000866  0.000150  0.000299
# 2013-12-17 23:59:59    2  Dogecoin   DOGE  0.000289  0.000116  0.000207
# 2013-12-18 23:59:59    3  Dogecoin   DOGE  0.000362  0.000205  0.000267
# 2013-12-19 23:59:59    4  Dogecoin   DOGE  0.001520  0.000328  0.000395
# 2013-12-20 23:59:59    5  Dogecoin   DOGE  0.001143  0.000662  0.001143
#
#                         Close  Volume     Marketcap
# Date
# 2013-12-16 23:59:59  0.000205     0.0  1.509085e+06
# 2013-12-17 23:59:59  0.000269     0.0  2.169688e+06
# 2013-12-18 23:59:59  0.000362     0.0  3.188943e+06
# 2013-12-19 23:59:59  0.001162     0.0  1.115034e+07
# 2013-12-20 23:59:59  0.000704     0.0  7.284337e+06

# %%
df_USDC.head()
# Out:
#                      SNo      Name Symbol     High      Low     Open    Close  \
# Date
# 2018-10-09 23:59:59    1  USD Coin   USDC  1.00833  1.00003  1.00427  1.00686
# 2018-10-10 23:59:59    2  USD Coin   USDC  1.01908  1.00397  1.00494  1.00962
# 2018-10-11 23:59:59    3  USD Coin   USDC  1.03123  1.00173  1.00994  1.00978
# 2018-10-12 23:59:59    4  USD Coin   USDC  1.01871  1.00114  1.00861  1.01272
# 2018-10-13 23:59:59    5  USD Coin   USDC  1.02029  1.00355  1.01445  1.00743
#
#                         Volume  Marketcap
# Date
# 2018-10-09 23:59:59   108803.0        0.0
# 2018-10-10 23:59:59   711783.0        0.0
# 2018-10-11 23:59:59  4177290.0        0.0
# 2018-10-12 23:59:59  1322240.0        0.0
# 2018-10-13 23:59:59   698507.0        0.0

# %%
df_bitcoin.index
# Out:
# DatetimeIndex(['2013-04-29 23:59:59', '2013-04-30 23:59:59',
#                '2013-05-01 23:59:59', '2013-05-02 23:59:59',
#                '2013-05-03 23:59:59', '2013-05-04 23:59:59',
#                '2013-05-05 23:59:59', '2013-05-06 23:59:59',
#                '2013-05-07 23:59:59', '2013-05-08 23:59:59',
#                ...
#                '2021-06-27 23:59:59', '2021-06-28 23:59:59',
#                '2021-06-29 23:59:59', '2021-06-30 23:59:59',
#                '2021-07-01 23:59:59', '2021-07-02 23:59:59',
#                '2021-07-03 23:59:59', '2021-07-04 23:59:59',
#                '2021-07-05 23:59:59', '2021-07-06 23:59:59'],
#               dtype='datetime64[ns]', name='Date', length=2991, freq=None)

# %%
plt.figure(figsize=(20,7))

plt.plot(df_bitcoin.index, df_bitcoin['Close'], color='red', label= '$ cierre Btc')
plt.plot()
plt.title('Tend. Precio de BTC en el tiempo')
plt.xlabel('Fecha')
plt.ylabel('Precio en USD')
#plt.gca().xaxis.set_major_formatter(mdates.DateFormatter('%Y-%M-%D'))
plt.gca().xaxis.set_major_locator(mdates.MonthLocator(interval=6))
plt.xticks(rotation=75)
plt.legend()
plt.show()

# %% [markdown]
# ### GRAFICO 3

# %%
plt.figure(figsize=(20,7))

plt.plot(df_bitcoin.index, df_bitcoin['Close'], color='red', label= 'BTC')
#plt.plot(df_bitcoin.index, df_bitcoin['High'], color= 'red', label='Precio Max', linestyle='--')
#plt.plot(df_bitcoin.index, df_bitcoin['Low'], color= 'red', label='Precio Min', linestyle='--')

plt.plot(df_cardano.index, df_cardano['Close'], color='g', label= 'ADA')
#plt.plot(df_cardano.index, df_cardano['High'],color='g', label='Precio Max', linestyle='-.')
#plt.plot(df_cardano.index, df_cardano['Low'],color='g', label='Precio Min', linestyle='--')

plt.plot(df_dogecoin.index, df_dogecoin['Close'], color= 'orange', label= 'DOG')
#plt.plot(df_dogecoin.index, df_dogecoin['High'], color= 'orange', label= 'P.Max', linestyle='--')
#plt.plot(df_dogecoin.index, df_dogecoin['Low'],color='orange', label='P.Min', linestyle='--')
plt.plot(df_ethereum.index, df_ethereum['Close'], color='purple', label='ETH')

plt.plot (df_polkadot.index, df_polkadot ['Close'], color= 'black', label='DOT') #cambiar color 
#plt.plot(df_polkadot.index, df_polkadot['High'], color= 'black', label='Precio Max', linestyle='-.')
#plt.plot(df_polkadot.index, df_polkadot['Low'],color= 'black', label='Precio Min', linestyle='--')
plt.plot(df_solana.index, df_solana['Close'],color="blue",label= 'SOL')

#plt.plot(df_tether.index, df_tether['Close'], color='yellow', label='USDT')
#plt.plot(df_USDC.index,df_USDC['Close'], color='lime', label='USDC')
plt.plot(df_XRP.index,df_XRP['Close'], color='gray',label='XRP')

plt.plot()
plt.title('Tend. Precio en el tiempo (Grafico 3)')
plt.xlabel('Fecha')
plt.ylabel('Precio en USD')
#plt.gca().xaxis.set_major_formatter(mdates.DateFormatter('%Y-%M-%D'))
plt.gca().xaxis.set_major_locator(mdates.MonthLocator(interval=6))
plt.yscale('log')
plt.gca().set_facecolor('lightblue') 
plt.xticks(rotation=75)
plt.legend()
plt.grid(True)
plt.show()

# %%
#PRUEBA 
plt.figure(figsize=(10,7)) 
sns.histplot(df_XRP['Marketcap'], bins=30, color='blue',kde=True , label= 'Precio de apertura')
# Out:
# <Axes: xlabel='Marketcap', ylabel='Count'>

# %%
plt.figure(figsize=(20,6))
plt.plot(df_bitcoin['Marketcap'], linestyle='--', color='gray')
plt.gca().set_facecolor('lightblue') 
plt.xlabel('Tiempo')
plt.ylabel('Valor')
plt.title('Marketcap BTC')
plt.show()

# %%
print(len('marketcap'))
# Out:
# 9

# %% [markdown]
# # COEFICIENTE DE PEARSON

# %%
from scipy.stats import pearsonr

# %%
df_XRP.head()
# Out:
#                      SNo Name Symbol      High       Low      Open     Close  \
# Date
# 2013-08-05 23:59:59    1  XRP    XRP  0.005980  0.005613  0.005875  0.005613
# 2013-08-06 23:59:59    2  XRP    XRP  0.005661  0.004629  0.005637  0.004680
# 2013-08-07 23:59:59    3  XRP    XRP  0.004682  0.004333  0.004669  0.004417
# 2013-08-08 23:59:59    4  XRP    XRP  0.004424  0.004175  0.004397  0.004254
# 2013-08-09 23:59:59    5  XRP    XRP  0.004367  0.004253  0.004257  0.004291
#
#                      Volume     Marketcap
# Date
# 2013-08-05 23:59:59     0.0  4.387916e+07
# 2013-08-06 23:59:59     0.0  3.659101e+07
# 2013-08-07 23:59:59     0.0  3.453412e+07
# 2013-08-08 23:59:59     0.0  3.325863e+07
# 2013-08-09 23:59:59     0.0  3.354750e+07

# %%
df_ethereum.head()
# Out:
#                      SNo      Name Symbol      High       Low      Open  \
# Date
# 2015-08-08 23:59:59    1  Ethereum    ETH  2.798810  0.714725  2.793760
# 2015-08-09 23:59:59    2  Ethereum    ETH  0.879810  0.629191  0.706136
# 2015-08-10 23:59:59    3  Ethereum    ETH  0.729854  0.636546  0.713989
# 2015-08-11 23:59:59    4  Ethereum    ETH  1.131410  0.663235  0.708087
# 2015-08-12 23:59:59    5  Ethereum    ETH  1.289940  0.883608  1.058750
#
#                         Close     Volume     Marketcap
# Date
# 2015-08-08 23:59:59  0.753325   674188.0  4.548689e+07
# 2015-08-09 23:59:59  0.701897   532170.0  4.239957e+07
# 2015-08-10 23:59:59  0.708448   405283.0  4.281836e+07
# 2015-08-11 23:59:59  1.067860  1463100.0  6.456929e+07
# 2015-08-12 23:59:59  1.217440  2150620.0  7.364501e+07

# %%
# quitar 'Date' como indice y ponerlo como columna 
df_bitcoin.reset_index(inplace=True)
df_ethereum.reset_index(inplace=True)

# %%
df_ethereum.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 2160 entries, 0 to 2159
# Data columns (total 10 columns):
#  #   Column     Non-Null Count  Dtype
# ---  ------     --------------  -----
#  0   Date       2160 non-null   datetime64[ns]
#  1   SNo        2160 non-null   int64
#  2   Name       2160 non-null   object
#  3   Symbol     2160 non-null   object
#  4   High       2160 non-null   float64
#  5   Low        2160 non-null   float64
#  6   Open       2160 non-null   float64
#  7   Close      2160 non-null   float64
#  8   Volume     2160 non-null   float64
#  9   Marketcap  2160 non-null   float64
# dtypes: datetime64[ns](1), float64(6), int64(1), object(2)
# memory usage: 168.9+ KB

# %%
df_bitcoin.head()
# Out:
#                  Date  SNo     Name Symbol        High         Low  \
# 0 2013-04-29 23:59:59    1  Bitcoin    BTC  147.488007  134.000000
# 1 2013-04-30 23:59:59    2  Bitcoin    BTC  146.929993  134.050003
# 2 2013-05-01 23:59:59    3  Bitcoin    BTC  139.889999  107.720001
# 3 2013-05-02 23:59:59    4  Bitcoin    BTC  125.599998   92.281898
# 4 2013-05-03 23:59:59    5  Bitcoin    BTC  108.127998   79.099998
#
#          Open       Close  Volume     Marketcap
# 0  134.444000  144.539993     0.0  1.603769e+09
# 1  144.000000  139.000000     0.0  1.542813e+09
# 2  139.000000  116.989998     0.0  1.298955e+09
# 3  116.379997  105.209999     0.0  1.168517e+09
# 4  106.250000   97.750000     0.0  1.085995e+09

# %%
print("Columnas en BTC:", df_bitcoin.columns)
print('columnas en ETH', df_ethereum.columns)
# Out:
# Columnas en BTC: Index(['Date', 'SNo', 'Name', 'Symbol', 'High', 'Low', 'Open', 'Close',
#        'Volume', 'Marketcap'],
#       dtype='object')
# columnas en ETH Index(['Date', 'SNo', 'Name', 'Symbol', 'High', 'Low', 'Open', 'Close',
#        'Volume', 'Marketcap'],
#       dtype='object')

# %%
# seleccionar solo dos columnas (High y Date)

''''
df_bitcoin=pd.read_csv(r"C:\Users\Usuario\Documents\Proyecto EDA\src\data\coin_Bitcoin.csv", usecols=['Date', 'High']) 
df_ethereum=pd.read_csv(r"C:\Users\Usuario\Documents\Proyecto EDA\src\data\coin_Ethereum.csv", usecols=['Date','High'])
print(df_bitcoin.head())
'''
# Out:
#   Cell In[69], line 7
#     '''
#        ^
# SyntaxError: (unicode error) 'unicodeescape' codec can't decode bytes in position 29-30: truncated \UXXXXXXXX escape

# %% [markdown]
# ## CORRELACIÓN ENTRE BTC Y ETH

# %%
df_bitcoin['Date'] = pd.to_datetime(df_bitcoin['Date'])
df_ethereum['Date'] = pd.to_datetime(df_ethereum['Date'])

df_merged = pd.merge(df_bitcoin, df_ethereum, on='Date', suffixes=('_btc', '_eth'))
btc_precio = df_merged['High_btc']
eth_precio = df_merged['High_eth']

corr, _ = pearsonr(btc_precio, eth_precio)
print(f"Coeficiente  entre BTC y ETH: {corr}")
# Out:
# Coeficiente  entre BTC y ETH: 0.9029174879246602

# %%
plt.figure(figsize=(8, 6))
sns.scatterplot(x=btc_precio, y=eth_precio, color='blue', alpha=0.6)
plt.title(f'Correlación de Pearson: {corr:.2f}', fontsize=14)
plt.xlabel('Precio BTC', fontsize=12)
plt.ylabel('Precio ETH', fontsize=12)
plt.show()

# %% [markdown]
# ### CALCULO DEL TIEMPO ENTRE BTC Y ETH

# %%
df_bitcoin['Date'] = pd.to_datetime(df_bitcoin['Date'])
df_ethereum['Date'] = pd.to_datetime(df_ethereum['Date'])
df_merged = pd.merge(df_bitcoin, df_ethereum, on='Date', suffixes=('_btc', '_eth'))
df_merged['btc_change'] = df_merged['Close_btc'].diff()
df_merged['eth_change'] = df_merged['Close_eth'].diff()

btc_up_dates = df_merged[df_merged['btc_change'] > 0]['Date']
eth_up_dates = df_merged[df_merged['eth_change'] > 0]['Date']

time_diffs = []
for btc_date in btc_up_dates:
    nearest_eth_date = eth_up_dates.iloc[(eth_up_dates - btc_date).abs().argmin()]
    time_diff = abs((nearest_eth_date - btc_date).days)
    time_diffs.append({'BTC Date': btc_date, 'ETH Date': nearest_eth_date, 'Tiempo de diferencia (dias)': time_diff})

time_diffs_df = pd.DataFrame(time_diffs)
print(time_diffs_df)
# Out:
#                 BTC Date            ETH Date  Tiempo de diferencia (dias)
# 0    2015-08-09 23:59:59 2015-08-10 23:59:59                            1
# 1    2015-08-11 23:59:59 2015-08-11 23:59:59                            0
# 2    2015-08-14 23:59:59 2015-08-14 23:59:59                            0
# 3    2015-08-19 23:59:59 2015-08-19 23:59:59                            0
# 4    2015-08-20 23:59:59 2015-08-20 23:59:59                            0
# ...                  ...                 ...                          ...
# 1187 2021-06-29 23:59:59 2021-06-29 23:59:59                            0
# 1188 2021-07-02 23:59:59 2021-07-02 23:59:59                            0
# 1189 2021-07-03 23:59:59 2021-07-03 23:59:59                            0
# 1190 2021-07-04 23:59:59 2021-07-04 23:59:59                            0
# 1191 2021-07-06 23:59:59 2021-07-06 23:59:59                            0
#
# [1192 rows x 3 columns]

# %% [markdown]
# ## CORRELACIÓN ENTRE BTC Y XRP

# %%
df_XRP.reset_index(inplace=True)
df_XRP['Date'] = pd.to_datetime(df_XRP['Date'])

#start_date = '2017-10-03 23:59:59'
#df_btc_filtered = df_bitcoin[df_bitcoin['Date'] >= start_date]
#df_xrp_filtered = df_ethereum[df_ethereum['Date'] >= start_date]

df_merged = pd.merge(df_bitcoin, df_XRP, on='Date', suffixes=('_btc', '_xrp'))
btc_precio = df_merged['High_btc']
xrp_precio = df_merged['High_xrp']

corr, _ = pearsonr(btc_precio, xrp_precio)
print(f'Coeficiente entre BTCy XPR:{corr}')
#print(f"Coeficiente  entre BTC y ETH:{start_date}: {corr}")
# Out:
# Coeficiente entre BTCy XPR:0.6165177518213837

# %%
plt.figure(figsize=(8, 6))
sns.scatterplot(x=btc_precio, y=xrp_precio, color='green', alpha=0.6)
plt.title(f'Correlación de Pearson: {corr:.2f}', fontsize=14)
plt.xlabel('Precio BTC', fontsize=12)
plt.ylabel('Precio XRP', fontsize=12)
plt.grid(True)
plt.show()

# %% [markdown]
# #### CALCULO DE TIEMPO ENTRE BTC Y XRP

# %%
df_bitcoin['Date'] = pd.to_datetime(df_bitcoin['Date'])
df_XRP['Date'] = pd.to_datetime(df_XRP['Date'])
df_merged = pd.merge(df_bitcoin, df_XRP, on='Date', suffixes=('_btc', '_xrp'))
df_merged['btc_change'] = df_merged['Close_btc'].diff()
df_merged['xrp_change'] = df_merged['Close_xrp'].diff()

btc_up_dates = df_merged[df_merged['btc_change'] > 0]['Date']
xrp_up_dates = df_merged[df_merged['xrp_change'] > 0]['Date']

time_diffs = []
for btc_date in btc_up_dates:
    nearest_xrp_date = xrp_up_dates.iloc[(xrp_up_dates - btc_date).abs().argmin()]
    time_diff = abs((nearest_xrp_date - btc_date).days)
    time_diffs.append({'BTC Date': btc_date, 'XRP Date': nearest_xrp_date, 'Tiempo de diferencia (dias)': time_diff})

time_diffs_df = pd.DataFrame(time_diffs)
print(time_diffs_df)
# Out:
#                 BTC Date            XRP Date  Tiempo de diferencia (dias)
# 0    2013-08-06 23:59:59 2013-08-09 23:59:59                            3
# 1    2013-08-10 23:59:59 2013-08-10 23:59:59                            0
# 2    2013-08-11 23:59:59 2013-08-11 23:59:59                            0
# 3    2013-08-12 23:59:59 2013-08-12 23:59:59                            0
# 4    2013-08-13 23:59:59 2013-08-12 23:59:59                            1
# ...                  ...                 ...                          ...
# 1557 2021-06-29 23:59:59 2021-06-29 23:59:59                            0
# 1558 2021-07-02 23:59:59 2021-07-03 23:59:59                            1
# 1559 2021-07-03 23:59:59 2021-07-03 23:59:59                            0
# 1560 2021-07-04 23:59:59 2021-07-04 23:59:59                            0
# 1561 2021-07-06 23:59:59 2021-07-06 23:59:59                            0
#
# [1562 rows x 3 columns]

# %% [markdown]
# ## CORRELACION ENTRE BTC Y ADA

# %%
df_cardano.head()
# Out:
#                      SNo     Name Symbol      High       Low      Open  \
# Date
# 2017-10-02 23:59:59    1  Cardano    ADA  0.030088  0.019969  0.024607
# 2017-10-03 23:59:59    2  Cardano    ADA  0.027425  0.020690  0.025757
# 2017-10-04 23:59:59    3  Cardano    ADA  0.022806  0.020864  0.020864
# 2017-10-05 23:59:59    4  Cardano    ADA  0.022154  0.020859  0.021951
# 2017-10-06 23:59:59    5  Cardano    ADA  0.021542  0.018360  0.021359
#
#                         Close      Volume     Marketcap
# Date
# 2017-10-02 23:59:59  0.025932  57641300.0  6.288991e+08
# 2017-10-03 23:59:59  0.020816  16997800.0  5.396927e+08
# 2017-10-04 23:59:59  0.021931   9000050.0  5.686195e+08
# 2017-10-05 23:59:59  0.021489   5562510.0  5.571390e+08
# 2017-10-06 23:59:59  0.018539   7780710.0  4.806646e+08

# %%
df_cardano.reset_index(inplace=True)

# %%
df_cardano['Date'] = pd.to_datetime(df_cardano['Date'])

start_date = '2017-10-03 23:59:59'
df_btc_filtered = df_bitcoin[df_bitcoin['Date'] >= start_date]
df_ada_filtered = df_cardano[df_cardano['Date'] >= start_date]

df_merged = pd.merge(df_bitcoin, df_cardano, on='Date', suffixes=('_btc', '_ada'))
btc_precio = df_merged['High_btc']
ada_precio = df_merged['High_ada']

corr, _ = pearsonr(btc_precio, ada_precio)
print(f"Coeficiente  entre BTC y ADA {start_date}: {corr}")
# Out:
# Coeficiente  entre BTC y ADA 2017-10-03 23:59:59: 0.854390914506703

# %%
plt.figure(figsize=(8, 6))
sns.scatterplot(x=btc_precio, y=ada_precio, color='purple', alpha=0.6)
plt.title(f'Correlación de Pearson: {corr:.2f}', fontsize=14)
plt.xlabel('Precio BTC', fontsize=12)
plt.ylabel('Precio ADA', fontsize=12)
plt.grid(True)
plt.show()

# %% [markdown]
# ### Calculo de tiemo

# %%
df_cardano.head()
# Out:
#                  Date  SNo     Name Symbol      High       Low      Open  \
# 0 2017-10-02 23:59:59    1  Cardano    ADA  0.030088  0.019969  0.024607
# 1 2017-10-03 23:59:59    2  Cardano    ADA  0.027425  0.020690  0.025757
# 2 2017-10-04 23:59:59    3  Cardano    ADA  0.022806  0.020864  0.020864
# 3 2017-10-05 23:59:59    4  Cardano    ADA  0.022154  0.020859  0.021951
# 4 2017-10-06 23:59:59    5  Cardano    ADA  0.021542  0.018360  0.021359
#
#       Close      Volume     Marketcap
# 0  0.025932  57641300.0  6.288991e+08
# 1  0.020816  16997800.0  5.396927e+08
# 2  0.021931   9000050.0  5.686195e+08
# 3  0.021489   5562510.0  5.571390e+08
# 4  0.018539   7780710.0  4.806646e+08

# %%
#df_cardano.drop('Date', axis=1, inplace=True) / esta linea borra una columna

# %%
df_bitcoin['Date'] = pd.to_datetime(df_bitcoin['Date'])
df_cardano['Date'] = pd.to_datetime(df_cardano['Date'])

start_date = '2017-10-03 23:59:59'
df_btc_filtered = df_bitcoin[df_bitcoin['Date'] >= start_date]
df_ada_filtered = df_cardano[df_cardano['Date'] >= start_date]

df_merged = pd.merge(df_bitcoin, df_cardano, on='Date', suffixes=('_btc', '_ada'))
df_merged['btc_change'] = df_merged['Close_btc'].diff()
df_merged['ada_change'] = df_merged['Close_ada'].diff()

btc_up_dates = df_merged[df_merged['btc_change'] > 0]['Date']
ada_up_dates = df_merged[df_merged['ada_change'] > 0]['Date']

time_diffs = []
for btc_date in btc_up_dates:
    nearest_ada_date = ada_up_dates.iloc[(ada_up_dates - btc_date).abs().argmin()]
    time_diff = abs((nearest_ada_date - btc_date).days)
    time_diffs.append({'BTC Date': btc_date, 'ADA Date': nearest_ada_date, 'Tiempo de diferencia (dias)': time_diff})

time_diffs_df = pd.DataFrame(time_diffs)
print(time_diffs_df)
# Out:
#                BTC Date            ADA Date  Tiempo de diferencia (dias)
# 0   2017-10-05 23:59:59 2017-10-04 23:59:59                            1
# 1   2017-10-06 23:59:59 2017-10-07 23:59:59                            1
# 2   2017-10-07 23:59:59 2017-10-07 23:59:59                            0
# 3   2017-10-08 23:59:59 2017-10-07 23:59:59                            1
# 4   2017-10-09 23:59:59 2017-10-09 23:59:59                            0
# ..                  ...                 ...                          ...
# 730 2021-06-29 23:59:59 2021-06-29 23:59:59                            0
# 731 2021-07-02 23:59:59 2021-07-02 23:59:59                            0
# 732 2021-07-03 23:59:59 2021-07-03 23:59:59                            0
# 733 2021-07-04 23:59:59 2021-07-04 23:59:59                            0
# 734 2021-07-06 23:59:59 2021-07-06 23:59:59                            0
#
# [735 rows x 3 columns]

# %% [markdown]
# ## CORRELACION ENTRE BTC Y USDC

# %%
df_USDC.reset_index(inplace=True) #REESTABLECER 'DATE' COMO INDICE.

# %%
df_USDC.head()
# Out:
#                  Date  SNo      Name Symbol     High      Low     Open  \
# 0 2018-10-09 23:59:59    1  USD Coin   USDC  1.00833  1.00003  1.00427
# 1 2018-10-10 23:59:59    2  USD Coin   USDC  1.01908  1.00397  1.00494
# 2 2018-10-11 23:59:59    3  USD Coin   USDC  1.03123  1.00173  1.00994
# 3 2018-10-12 23:59:59    4  USD Coin   USDC  1.01871  1.00114  1.00861
# 4 2018-10-13 23:59:59    5  USD Coin   USDC  1.02029  1.00355  1.01445
#
#      Close     Volume  Marketcap
# 0  1.00686   108803.0        0.0
# 1  1.00962   711783.0        0.0
# 2  1.00978  4177290.0        0.0
# 3  1.01272  1322240.0        0.0
# 4  1.00743   698507.0        0.0

# %%
df_USDC['Date'] = pd.to_datetime(df_USDC['Date'])

start_date = '2018-10-09 23:59:59'
df_btc_filtered = df_bitcoin[df_bitcoin['Date'] >= start_date]
df_USDC_filtered = df_USDC[df_USDC['Date'] >= start_date]

df_merged = pd.merge(df_bitcoin, df_USDC, on='Date', suffixes=('_btc', '_USDC'))
btc_precio = df_merged['High_btc']
USDC_precio = df_merged['High_USDC']

corr, _ = pearsonr(btc_precio, USDC_precio)
print(f"Coeficiente  entre BTC y USDC {start_date}: {corr}")
# Out:
# Coeficiente  entre BTC y USDC 2018-10-09 23:59:59: -0.4629542860158722

# %%
plt.figure(figsize=(8, 6))
sns.scatterplot(x=btc_precio, y=USDC_precio, color='purple', alpha=0.6)
plt.title(f'Correlación de Pearson: {corr:.2f}', fontsize=14)
plt.xlabel('Precio BTC', fontsize=12)
plt.ylabel('Precio USDC', fontsize=12)
plt.grid(True)
plt.show()

# %%
df_bitcoin['Date'] = pd.to_datetime(df_bitcoin['Date'])
df_USDC['Date'] = pd.to_datetime(df_USDC['Date'])

start_date = '2018-10-09 23:59:59'
df_btc_filtered = df_bitcoin[df_bitcoin['Date'] >= start_date]
df_USDC_filtered = df_USDC[df_USDC['Date'] >= start_date]

df_merged = pd.merge(df_bitcoin, df_USDC, on='Date', suffixes=('_btc', '_USDC'))
df_merged['btc_change'] = df_merged['Close_btc'].diff()
df_merged['USDC_change'] = df_merged['Close_USDC'].diff()

btc_up_dates = df_merged[df_merged['btc_change'] > 0]['Date']
USDC_up_dates = df_merged[df_merged['USDC_change'] > 0]['Date']

time_diffs = []
for btc_date in btc_up_dates:
    nearest_USDC_date = ada_up_dates.iloc[(ada_up_dates - btc_date).abs().argmin()]
    time_diff = abs((nearest_USDC_date - btc_date).days)
    time_diffs.append({'BTC Date': btc_date, 'USDC Date': nearest_ada_date, 'Tiempo de diferencia (dias)': time_diff})

time_diffs_df = pd.DataFrame(time_diffs)
print(time_diffs_df)
# Out:
#                BTC Date           USDC Date  Tiempo de diferencia (dias)
# 0   2018-10-12 23:59:59 2021-07-06 23:59:59                            0
# 1   2018-10-13 23:59:59 2021-07-06 23:59:59                            1
# 2   2018-10-14 23:59:59 2021-07-06 23:59:59                            1
# 3   2018-10-15 23:59:59 2021-07-06 23:59:59                            0
# 4   2018-10-20 23:59:59 2021-07-06 23:59:59                            0
# ..                  ...                 ...                          ...
# 526 2021-06-29 23:59:59 2021-07-06 23:59:59                            0
# 527 2021-07-02 23:59:59 2021-07-06 23:59:59                            0
# 528 2021-07-03 23:59:59 2021-07-06 23:59:59                            0
# 529 2021-07-04 23:59:59 2021-07-06 23:59:59                            0
# 530 2021-07-06 23:59:59 2021-07-06 23:59:59                            0
#
# [531 rows x 3 columns]

# %%
plt.figure(figsize=(12, 6))
plt.bar(time_diffs_df['BTC Date'], time_diffs_df['Tiempo de diferencia (dias)'], color='skyblue')
plt.xlabel('Fecha de aumento de BTC')
plt.ylabel('Diferencia de tiempo (días)')
plt.title('Diferencia de tiempo entre aumentos de BTC y USDC')
plt.xticks(rotation=45)
plt.tight_layout()
plt.show()
